# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Collecting kenpombuild==0.1
#   Downloading kenpombuild-0.1-py3-none-any.whl (2.2 kB)
# Collecting kenpompy
#   Downloading kenpompy-0.3.4-py3-none-any.whl (27 kB)
# Collecting html5lib==1.1
#   Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 KB 19.6 MB/s eta 0:00:00
# Collecting datetime
#   Downloading DateTime-5.1-py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 KB 8.8 MB/s eta 0:00:00
# Collecting bs4
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: Click in /shared-libs/python3.9/py/lib/python3.9/site-packages (from kenpombuild==0.1->-r ./requirements.txt (line 1)) (8.1.3)
# Requirement already satisfied: requests in /shared-libs/python3.9/py/lib/python3.9/site-packages (from kenpombuild==0.1->-r ./requirements.txt (line 1)) (2.28.1)
# Requirement already satisfied: webencodings in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from html5lib==1.1->-r ./requirements.txt (line 3)) (0.5.1)
# Requirement already satisfied: six>=1.9 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from html5lib==1.1->-r ./requirements.txt (line 3)) (1.16.0)
# Collecting mechanicalsoup
#   Downloading MechanicalSoup-1.2.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: pandas in /shared-libs/python3.9/py/lib/python3.9/site-packages (from kenpompy->-r ./requirements.txt (line 2)) (1.2.5)
# Requirement already satisfied: beautifulsoup4 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from bs4->kenpombuild==0.1->-r ./requirements.txt (line 1)) (4.11.1)
# Requirement already satisfied: zope.interface in /shared-libs/python3.9/py/lib/python3.9/site-packages (from datetime->kenpombuild==0.1->-r ./requirements.txt (line 1)) (5.5.0)
# Requirement already satisfied: pytz in /shared-libs/python3.9/py/lib/python3.9/site-packages (from datetime->kenpombuild==0.1->-r ./requirements.txt (line 1)) (2022.5)
# Requirement already satisfied: lxml in /shared-libs/python3.9/py/lib/python3.9/site-packages (from mechanicalsoup->kenpompy->-r ./requirements.txt (line 2)) (4.9.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests->kenpombuild==0.1->-r ./requirements.txt (line 1)) (1.26.12)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests->kenpombuild==0.1->-r ./requirements.txt (line 1)) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests->kenpombuild==0.1->-r ./requirements.txt (line 1)) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests->kenpombuild==0.1->-r ./requirements.txt (line 1)) (2.1.1)
# Requirement already satisfied: numpy>=1.16.5 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas->kenpompy->-r ./requirements.txt (line 2)) (1.23.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from pandas->kenpompy->-r ./requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: soupsieve>1.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from beautifulsoup4->bs4->kenpombuild==0.1->-r ./requirements.txt (line 1)) (2.3.2.post1)
# Requirement already satisfied: setuptools in /root/venv/lib/python3.9/site-packages (from zope.interface->datetime->kenpombuild==0.1->-r ./requirements.txt (line 1)) (58.1.0)
# Building wheels for collected packages: bs4
#   Building wheel for bs4 (setup.py): started
#   Building wheel for bs4 (setup.py): finished with status 'done'
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1271 sha256=977697271646b0296160f3e9a088266d656536232453b22087ce80103c933f84
#   Stored in directory: /root/.cache/pip/wheels/73/2b/cb/099980278a0c9a3e57ff1a89875ec07bfa0b6fcbebb9a8cad3
# Successfully built bs4
# Installing collected packages: html5lib, mechanicalsoup, datetime, bs4, kenpompy, kenpombuild
# Successfully installed bs4-0.0.1 datetime-5.1 html5lib-1.1 kenpombuild-0.1 kenpompy-0.3.4 mechanicalsoup-1.2.0
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=76c1b032-5d0a-4d37-bf01-322f3e813bd4' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
